# %%
'''
Classification - Predicting Customer Churn (Will the customer leave?)

Goal: Predict whether a customer will churn (Yes=1) or not (No=0).

Model: Logistic Regression (Predicts the probability of a binary outcome).

create sample data

data = {

 'MonthlyCharge': [50, 80, 70, 40, 90, 60, 100, 85, 45, 75],

 'ContractLength': [12, 6, 24, 12, 3, 18, 24, 6, 12, 18],

 'Age': [30, 25, 40, 35, 28, 50, 45, 32, 29, 55],

 'Churn': [0, 1, 0, 0, 1, 0, 0, 1, 0, 0] # 0 = No Churn, 1 = Churn

}

'''
# Out:
# "\nClassification - Predicting Customer Churn (Will the customer leave?)\n\nGoal: Predict whether a customer will churn (Yes=1) or not (No=0).\n\nModel: Logistic Regression (Predicts the probability of a binary outcome).\n\ncreate sample data\n\ndata = {\n\n 'MonthlyCharge': [50, 80, 70, 40, 90, 60, 100, 85, 45, 75],\n\n 'ContractLength': [12, 6, 24, 12, 3, 18, 24, 6, 12, 18],\n\n 'Age': [30, 25, 40, 35, 28, 50, 45, 32, 29, 55],\n\n 'Churn': [0, 1, 0, 0, 1, 0, 0, 1, 0, 0] # 0 = No Churn, 1 = Churn\n\n}\n\n"

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, precision_score, recall_score

# %%
data = {

 'MonthlyCharge': [50, 80, 70, 40, 90, 60, 100, 85, 45, 75],

 'ContractLength': [12, 6, 24, 12, 3, 18, 24, 6, 12, 18],

 'Age': [30, 25, 40, 35, 28, 50, 45, 32, 29, 55],

 'Churn': [0, 1, 0, 0, 1, 0, 0, 1, 0, 0] # 0 = No Churn, 1 = Churn

}

# %%
df = pd.DataFrame(data)

x = df[['MonthlyCharge', 'ContractLength', 'Age']]
y = df['Churn']

# %%
#Data splitting
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
#Creation, fittinf and prediction
model = LogisticRegression()

model.fit(x_train, y_train)

y_predict = model.predict(x_test)

# %%
#Evaluation
acc_score = accuracy_score(y_true= y_test, y_pred= y_predict)
prec_score = precision_score(y_true= y_test, y_pred= y_predict)
rec_score = recall_score(y_true= y_test, y_pred= y_predict)
f_score = f1_score(y_true= y_test, y_pred= y_predict)
conf_matrix = confusion_matrix(y_true= y_test, y_pred= y_predict)

# %%
#OUTPUT
print("---RESULTS---")
print(f"Prediction: {y_predict}")
print(f"Actual Churn: {y_test.values}")
print(f"Accuracy Score: {acc_score}")
print(f"Precision Score: {prec_score}")
print(f"Recall Score: {rec_score}")
print(f"F1 Score: {f_score}")
print(f"Confusion Matric: {conf_matrix}")
# Out:
# ---RESULTS---
# Prediction: [0 1]
# Actual Churn: [0 1]
# Accuracy Score: 1.0
# Precision Score: 1.0
# Recall Score: 1.0
# F1 Score: 1.0
# Confusion Matric: [[1 0]
#  [0 1]]
